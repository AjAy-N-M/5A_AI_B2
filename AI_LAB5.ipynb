# %%
print("Ajay N M")
print("USN: 1BM22CS026")
import random
from math import exp
import time
from copy import deepcopy

N_QUEENS = 8
TEMPERATURE = 100

def threat_calculate(n):
    '''Combination formula for calculating attacking pairs.'''
    if n < 2:
        return 0
    return (n - 1) * n / 2

def create_board(n):
    '''Create a chessboard with one queen per column, randomly placed.'''
    chess_board = {}
    temp = list(range(n))
    random.shuffle(temp)  # Shuffle to randomize the initial board
    for column in range(n):
        chess_board[column] = temp[column]
    return chess_board

def cost(chess_board):
    '''Calculate the number of attacking queen pairs.'''
    threat = 0
    m_chessboard = {}
    a_chessboard = {}

    for column in chess_board:
        temp_m = column - chess_board[column]
        temp_a = column + chess_board[column]
        m_chessboard[temp_m] = m_chessboard.get(temp_m, 0) + 1
        a_chessboard[temp_a] = a_chessboard.get(temp_a, 0) + 1

    for count in m_chessboard.values():
        threat += threat_calculate(count)
    for count in a_chessboard.values():
        threat += threat_calculate(count)

    return threat

def print_chess_board(board, count):
    '''Print the chess board.'''
    print("Iteration:", count)
    for row in range(N_QUEENS):
        line = ""
        for col in range(N_QUEENS):
            if board[col] == row:
                line += "Q "
            else:
                line += ". "
        print(line)
    print("\n")

def simulated_annealing():
    '''Simulated Annealing for N-Queens Problem.'''
    solution_found = False
    answer = create_board(N_QUEENS)
    cost_answer = cost(answer)
    count = 0

    t = TEMPERATURE
    cooling_rate = 0.99

    while t > 0:
        count += 1
        t *= cooling_rate

        # Generate a new successor by swapping two randomly chosen columns
        successor = deepcopy(answer)
        index_1, index_2 = random.sample(range(N_QUEENS), 2)
        successor[index_1], successor[index_2] = successor[index_2], successor[index_1]

        successor_cost = cost(successor)
        delta = successor_cost - cost_answer

        # Calculate the probability of accepting the successor
        if delta < 0:
            acceptance_probability = 1.0
        else:
            acceptance_probability = exp(-delta / t)

        # Decide whether to accept the new state
        if delta < 0 or random.uniform(0, 1) < acceptance_probability:
            answer = deepcopy(successor)
            cost_answer = successor_cost

        # Print board, cost, and probability at each iteration
        print(f"Iteration {count}, Temperature: {t:.4f}")
        print("Board configuration:")
        print_chess_board(answer, count)
        print(f"Current cost: {cost_answer}")
        print(f"Acceptance probability: {acceptance_probability:.4f}\n")

        # Check if solution is found
        if cost_answer == 0:
            solution_found = True
            print("Solution found!")
            print_chess_board(answer, count)
            break

    if not solution_found:
        print("Failed to find a solution.")

def main():
    start = time.time()
    simulated_annealing()
    print("Runtime in seconds:", time.time() - start)

if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
# . . . . . Q . .
# . . . . . . . Q
# . . . . . . Q .
# . . . Q . . . .
# . . Q . . . . .
# . . . . Q . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 91, Temperature: 40.0685
# Board configuration:
# Iteration: 91
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . . . . Q
# . . . . . Q . .
# . . . Q . . . .
# . . Q . . . . .
# . . . . Q . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.9513
#
# Iteration 92, Temperature: 39.6678
# Board configuration:
# Iteration: 92
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . . . . Q
# . . . . . Q . .
# . . . . Q . . .
# . . Q . . . . .
# . . . Q . . . .
#
#
# Current cost: 6.0
# Acceptance probability: 0.9751
#
# Iteration 93, Temperature: 39.2711
# Board configuration:
# Iteration: 93
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . . . . Q
# . . . . . Q . .
# . . . Q . . . .
# . . Q . . . . .
# . . . . Q . . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 94, Temperature: 38.8784
# Board configuration:
# Iteration: 94
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . . . . Q
# . . . . . Q . .
# . . . Q . . . .
# . . Q . . . . .
# . . . . Q . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.9499
#
# Iteration 95, Temperature: 38.4896
# Board configuration:
# Iteration: 95
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . . Q . .
# . . . . . . . Q
# . . . Q . . . .
# . . Q . . . . .
# . . . . Q . . .
#
#
# Current cost: 8.0
# Acceptance probability: 0.9250
#
# Iteration 96, Temperature: 38.1047
# Board configuration:
# Iteration: 96
# Q . . . . . . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . . . . Q .
# . . Q . . . . .
# . . . . Q . . .
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 97, Temperature: 37.7237
# Board configuration:
# Iteration: 97
# Q . . . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . . . . Q .
# . . Q . . . . .
# . . . . Q . . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 98, Temperature: 37.3464
# Board configuration:
# Iteration: 98
# Q . . . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . Q . . . . .
# . . . . . . Q .
# . . . . Q . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 99, Temperature: 36.9730
# Board configuration:
# Iteration: 99
# Q . . . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . . . . Q
# . . Q . . . . .
# . . . . . Q . .
# . . . . Q . . .
#
#
# Current cost: 6.0
# Acceptance probability: 0.9473
#
# Iteration 100, Temperature: 36.6032
# Board configuration:
# Iteration: 100
# Q . . . . . . .
# . . . Q . . . .
# . . . . . Q . .
# . . . . . . Q .
# . . . . . . . Q
# . . Q . . . . .
# . Q . . . . . .
# . . . . Q . . .
#
#
# Current cost: 8.0
# Acceptance probability: 0.9468
#
# Iteration 101, Temperature: 36.2372
# Board configuration:
# Iteration: 101
# Q . . . . . . .
# . . . Q . . . .
# . . . . . Q . .
# . . . . . . Q .
# . . . . . . . Q
# . . Q . . . . .
# . . . . Q . . .
# . Q . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 102, Temperature: 35.8748
# Board configuration:
# Iteration: 102
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . Q .
# . . . . . Q . .
# . . . . . . . Q
# . . Q . . . . .
# . . . . Q . . .
# . Q . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 103, Temperature: 35.5161
# Board configuration:
# Iteration: 103
# Q . . . . . . .
# . . . . . Q . .
# . . . . . . Q .
# . . . Q . . . .
# . . . . . . . Q
# . . Q . . . . .
# . . . . Q . . .
# . Q . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 104, Temperature: 35.1609
# Board configuration:
# Iteration: 104
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . Q .
# . . . Q . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . Q . . .
# . Q . . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 105, Temperature: 34.8093
# Board configuration:
# Iteration: 105
# . . Q . . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . Q . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . Q . . .
# . . . . . Q . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 106, Temperature: 34.4612
# Board configuration:
# Iteration: 106
# . . . . . . Q .
# . Q . . . . . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . Q . . .
# . . . . . Q . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.9436
#
# Iteration 107, Temperature: 34.1166
# Board configuration:
# Iteration: 107
# . . . . . . Q .
# . Q . . . . . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . Q . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . . . Q . .
#
#
# Current cost: 7.0
# Acceptance probability: 0.9431
#
# Iteration 108, Temperature: 33.7754
# Board configuration:
# Iteration: 108
# . . . . . . Q .
# Q . . . . . . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . . Q . .
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 109, Temperature: 33.4377
# Board configuration:
# Iteration: 109
# . . . . . . Q .
# . . Q . . . . .
# Q . . . . . . .
# . . . Q . . . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . . Q . .
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 110, Temperature: 33.1033
# Board configuration:
# Iteration: 110
# . . . . . . Q .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . Q . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 111, Temperature: 32.7723
# Board configuration:
# Iteration: 111
# . . . . . . Q .
# . . Q . . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# Q . . . . . . .
# . . . Q . . . .
# . . . . . Q . .
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 112, Temperature: 32.4446
# Board configuration:
# Iteration: 112
# . . . . . . Q .
# . . Q . . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . Q . . . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . Q . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.9117
#
# Iteration 113, Temperature: 32.1201
# Board configuration:
# Iteration: 113
# . . . . . . Q .
# . Q . . . . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . Q . . . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . Q . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 114, Temperature: 31.7989
# Board configuration:
# Iteration: 114
# . . . . . . Q .
# . Q . . . . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . Q . . . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . Q . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.9100
#
# Iteration 115, Temperature: 31.4809
# Board configuration:
# Iteration: 115
# . . . . . . Q .
# . Q . . . . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . Q . . . .
# Q . . . . . . .
# . . . . . Q . .
# . . . . Q . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 116, Temperature: 31.1661
# Board configuration:
# Iteration: 116
# . . . . . . Q .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . Q . . . . . .
# . . . . . Q . .
# . . . . Q . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.9378
#
# Iteration 117, Temperature: 30.8544
# Board configuration:
# Iteration: 117
# . . . . . Q . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . Q . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 118, Temperature: 30.5459
# Board configuration:
# Iteration: 118
# . . . . . . . Q
# Q . . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . Q . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.9678
#
# Iteration 119, Temperature: 30.2404
# Board configuration:
# Iteration: 119
# . . . . . . . Q
# Q . . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . Q . . . .
# . . . . Q . . .
# . . . . . . Q .
# . Q . . . . . .
#
#
# Current cost: 6.0
# Acceptance probability: 0.9056
#
# Iteration 120, Temperature: 29.9380
# Board configuration:
# Iteration: 120
# . . . . . . . Q
# . Q . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . Q . . . .
# . . . . Q . . .
# . . . . . . Q .
# Q . . . . . . .
#
#
# Current cost: 7.0
# Acceptance probability: 0.9671
#
# Iteration 121, Temperature: 29.6387
# Board configuration:
# Iteration: 121
# . . . . . . . Q
# . Q . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . Q . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 122, Temperature: 29.3423
# Board configuration:
# Iteration: 122
# . . . . . . Q .
# . Q . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . . Q . . .
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 123, Temperature: 29.0488
# Board configuration:
# Iteration: 123
# . . . . . . Q .
# . Q . . . . . .
# . . . . Q . . .
# . . . . . Q . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . Q . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.9335
#
# Iteration 124, Temperature: 28.7584
# Board configuration:
# Iteration: 124
# . . . . . Q . .
# . Q . . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . Q . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 125, Temperature: 28.4708
# Board configuration:
# Iteration: 125
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . Q . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.9655
#
# Iteration 126, Temperature: 28.1861
# Board configuration:
# Iteration: 126
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . Q . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . . . . Q
# . . Q . . . . .
#
#
# Current cost: 7.0
# Acceptance probability: 0.8990
#
# Iteration 127, Temperature: 27.9042
# Board configuration:
# Iteration: 127
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . Q . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 128, Temperature: 27.6252
# Board configuration:
# Iteration: 128
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . . . Q . .
# Q . . . . . . .
# . . . . . . . Q
# . . Q . . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.9644
#
# Iteration 129, Temperature: 27.3489
# Board configuration:
# Iteration: 129
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . . Q
# . . Q . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 130, Temperature: 27.0754
# Board configuration:
# Iteration: 130
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . . Q
# . . Q . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 131, Temperature: 26.8047
# Board configuration:
# Iteration: 131
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 132, Temperature: 26.5366
# Board configuration:
# Iteration: 132
# Q . . . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . Q . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.9274
#
# Iteration 133, Temperature: 26.2713
# Board configuration:
# Iteration: 133
# Q . . . . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . Q .
# . . . Q . . . .
# . . . . Q . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.9267
#
# Iteration 134, Temperature: 26.0085
# Board configuration:
# Iteration: 134
# Q . . . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . Q . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 135, Temperature: 25.7485
# Board configuration:
# Iteration: 135
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 136, Temperature: 25.4910
# Board configuration:
# Iteration: 136
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . . Q
# . . Q . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.8890
#
# Iteration 137, Temperature: 25.2361
# Board configuration:
# Iteration: 137
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . . Q . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . . Q
# . . Q . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 138, Temperature: 24.9837
# Board configuration:
# Iteration: 138
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . . . Q . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
#
#
# Current cost: 7.0
# Acceptance probability: 0.8869
#
# Iteration 139, Temperature: 24.7339
# Board configuration:
# Iteration: 139
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . . . Q . . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . Q .
# . Q . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 140, Temperature: 24.4865
# Board configuration:
# Iteration: 140
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . Q .
# . . . . Q . . .
#
#
# Current cost: 8.0
# Acceptance probability: 0.8493
#
# Iteration 141, Temperature: 24.2417
# Board configuration:
# Iteration: 141
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . Q .
# . . . . Q . . .
#
#
# Current cost: 11.0
# Acceptance probability: 0.8836
#
# Iteration 142, Temperature: 23.9992
# Board configuration:
# Iteration: 142
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . Q .
# Q . . . . . . .
#
#
# Current cost: 7.0
# Acceptance probability: 1.0000
#
# Iteration 143, Temperature: 23.7593
# Board configuration:
# Iteration: 143
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . . . . . . Q .
# . . . . . Q . .
# . . Q . . . . .
# Q . . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 144, Temperature: 23.5217
# Board configuration:
# Iteration: 144
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . Q .
# Q . . . . . . .
#
#
# Current cost: 7.0
# Acceptance probability: 0.8803
#
# Iteration 145, Temperature: 23.2864
# Board configuration:
# Iteration: 145
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . . Q . . . . .
# . . . . . Q . .
# Q . . . . . . .
# . . . . . . Q .
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 146, Temperature: 23.0536
# Board configuration:
# Iteration: 146
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . . Q . . . . .
# . . . . . Q . .
# Q . . . . . . .
# . . . . . . Q .
#
#
# Current cost: 6.0
# Acceptance probability: 0.8780
#
# Iteration 147, Temperature: 22.8230
# Board configuration:
# Iteration: 147
# . . . . Q . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . . . . Q . .
# Q . . . . . . .
# . . . . . . Q .
#
#
# Current cost: 8.0
# Acceptance probability: 0.9161
#
# Iteration 148, Temperature: 22.5948
# Board configuration:
# Iteration: 148
# . . . . . . Q .
# . Q . . . . . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . . . . Q . .
# Q . . . . . . .
# . . . . Q . . .
#
#
# Current cost: 10.0
# Acceptance probability: 0.9153
#
# Iteration 149, Temperature: 22.3689
# Board configuration:
# Iteration: 149
# . . . . . . Q .
# . . . Q . . . .
# . . Q . . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . . Q . .
# Q . . . . . . .
# . . . . Q . . .
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 150, Temperature: 22.1452
# Board configuration:
# Iteration: 150
# . . . . . . Q .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# Q . . . . . . .
# . . . . Q . . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 151, Temperature: 21.9237
# Board configuration:
# Iteration: 151
# . . . . . . Q .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . Q . .
# . . . . Q . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 152, Temperature: 21.7045
# Board configuration:
# Iteration: 152
# . . . Q . . . .
# . . . . . . Q .
# . . . . . . . Q
# . Q . . . . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . Q . .
# . . . . Q . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 153, Temperature: 21.4874
# Board configuration:
# Iteration: 153
# . . . Q . . . .
# . . . . . . Q .
# . . . . . . . Q
# . Q . . . . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . Q . .
# . . . . Q . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.9111
#
# Iteration 154, Temperature: 21.2726
# Board configuration:
# Iteration: 154
# . . . Q . . . .
# . . . . . . Q .
# . . . . . . . Q
# . Q . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# Q . . . . . . .
# . . . . Q . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 155, Temperature: 21.0598
# Board configuration:
# Iteration: 155
# . . . Q . . . .
# . . . . . . . Q
# . . . . . . Q .
# . Q . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# Q . . . . . . .
# . . . . Q . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 156, Temperature: 20.8492
# Board configuration:
# Iteration: 156
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . . Q . . .
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 157, Temperature: 20.6408
# Board configuration:
# Iteration: 157
# . . . . Q . . .
# Q . . . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . Q . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.8647
#
# Iteration 158, Temperature: 20.4343
# Board configuration:
# Iteration: 158
# . Q . . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . Q . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.9522
#
# Iteration 159, Temperature: 20.2300
# Board configuration:
# Iteration: 159
# . . . . . . . Q
# Q . . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 160, Temperature: 20.0277
# Board configuration:
# Iteration: 160
# . . . . . . . Q
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 161, Temperature: 19.8274
# Board configuration:
# Iteration: 161
# . . . . . . . Q
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.9041
#
# Iteration 162, Temperature: 19.6292
# Board configuration:
# Iteration: 162
# . . . . . . . Q
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.9031
#
# Iteration 163, Temperature: 19.4329
# Board configuration:
# Iteration: 163
# . . . . . . . Q
# Q . . . . . . .
# . . . . Q . . .
# . . . Q . . . .
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . Q .
#
#
# Current cost: 6.0
# Acceptance probability: 0.8569
#
# Iteration 164, Temperature: 19.2385
# Board configuration:
# Iteration: 164
# . . . . Q . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . Q .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 165, Temperature: 19.0461
# Board configuration:
# Iteration: 165
# . . . . Q . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . . Q . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . . Q . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 166, Temperature: 18.8557
# Board configuration:
# Iteration: 166
# . . . . Q . . .
# . . . Q . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . Q . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . . Q . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 167, Temperature: 18.6671
# Board configuration:
# Iteration: 167
# . . . . . . Q .
# . . . Q . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . Q . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.9478
#
# Iteration 168, Temperature: 18.4805
# Board configuration:
# Iteration: 168
# . . . . . . Q .
# . . . Q . . . .
# . . . . . . . Q
# . . Q . . . . .
# Q . . . . . . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . Q . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 169, Temperature: 18.2957
# Board configuration:
# Iteration: 169
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . Q . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . Q . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 170, Temperature: 18.1127
# Board configuration:
# Iteration: 170
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . . . . . Q .
# . . Q . . . . .
# . Q . . . . . .
# . . . . . Q . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.9463
#
# Iteration 171, Temperature: 17.9316
# Board configuration:
# Iteration: 171
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . . . . Q . .
# . . Q . . . . .
# . Q . . . . . .
# . . . . . . Q .
#
#
# Current cost: 5.0
# Acceptance probability: 0.9458
#
# Iteration 172, Temperature: 17.7523
# Board configuration:
# Iteration: 172
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . . . . Q . .
# . . . . . . Q .
# . Q . . . . . .
# . . Q . . . . .
#
#
# Current cost: 8.0
# Acceptance probability: 0.8445
#
# Iteration 173, Temperature: 17.5747
# Board configuration:
# Iteration: 173
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . Q . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 174, Temperature: 17.3990
# Board configuration:
# Iteration: 174
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . Q . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.9441
#
# Iteration 175, Temperature: 17.2250
# Board configuration:
# Iteration: 175
# . . . Q . . . .
# . . . . . . Q .
# . . . . . . . Q
# . . Q . . . . .
# . . . . . Q . .
# Q . . . . . . .
# . Q . . . . . .
# . . . . Q . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.9436
#
# Iteration 176, Temperature: 17.0527
# Board configuration:
# Iteration: 176
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . Q . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 177, Temperature: 16.8822
# Board configuration:
# Iteration: 177
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . Q . . .
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 178, Temperature: 16.7134
# Board configuration:
# Iteration: 178
# . . . Q . . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . . . . Q .
# . Q . . . . . .
# . . . . Q . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.8357
#
# Iteration 179, Temperature: 16.5463
# Board configuration:
# Iteration: 179
# . . . . Q . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . . . . Q .
# . Q . . . . . .
# . . . Q . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 180, Temperature: 16.3808
# Board configuration:
# Iteration: 180
# . . . . Q . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . . . . Q .
# Q . . . . . . .
# . . . Q . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.9408
#
# Iteration 181, Temperature: 16.2170
# Board configuration:
# Iteration: 181
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . . Q . .
# . . . . . . . Q
# . . Q . . . . .
# Q . . . . . . .
# . . . Q . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 182, Temperature: 16.0548
# Board configuration:
# Iteration: 182
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.8829
#
# Iteration 183, Temperature: 15.8943
# Board configuration:
# Iteration: 183
# . . . . . . Q .
# . Q . . . . . .
# . . . . Q . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
#
#
# Current cost: 9.0
# Acceptance probability: 0.7301
#
# Iteration 184, Temperature: 15.7353
# Board configuration:
# Iteration: 184
# . . . . . . . Q
# . Q . . . . . .
# . . . . Q . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . Q . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 185, Temperature: 15.5780
# Board configuration:
# Iteration: 185
# . . . . . . Q .
# . Q . . . . . .
# . . . . Q . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
#
#
# Current cost: 9.0
# Acceptance probability: 0.7254
#
# Iteration 186, Temperature: 15.4222
# Board configuration:
# Iteration: 186
# . . . . . . Q .
# . Q . . . . . .
# . . . . Q . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
#
#
# Current cost: 9.0
# Acceptance probability: 0.7715
#
# Iteration 187, Temperature: 15.2680
# Board configuration:
# Iteration: 187
# . . . . . . Q .
# . Q . . . . . .
# Q . . . . . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . . Q . . . .
#
#
# Current cost: 7.0
# Acceptance probability: 1.0000
#
# Iteration 188, Temperature: 15.1153
# Board configuration:
# Iteration: 188
# . . . . . . Q .
# . Q . . . . . .
# Q . . . . . . .
# . . . . . Q . .
# . . . . Q . . .
# . . . . . . . Q
# . . Q . . . . .
# . . . Q . . . .
#
#
# Current cost: 7.0
# Acceptance probability: 1.0000
#
# Iteration 189, Temperature: 14.9641
# Board configuration:
# Iteration: 189
# . . . . . . Q .
# . . . . Q . . .
# Q . . . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . . Q
# . . Q . . . . .
# . . . Q . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 190, Temperature: 14.8145
# Board configuration:
# Iteration: 190
# . . . . . . Q .
# . . . . . Q . .
# Q . . . . . . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# . . Q . . . . .
# . . . Q . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 191, Temperature: 14.6664
# Board configuration:
# Iteration: 191
# . . . . . . Q .
# . . . . . Q . .
# Q . . . . . . .
# . . . . Q . . .
# . . . Q . . . .
# . . . . . . . Q
# . . Q . . . . .
# . Q . . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.9341
#
# Iteration 192, Temperature: 14.5197
# Board configuration:
# Iteration: 192
# . . . . . . Q .
# . . . . . Q . .
# . . Q . . . . .
# . . . . Q . . .
# . . . Q . . . .
# . . . . . . . Q
# Q . . . . . . .
# . Q . . . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.8713
#
# Iteration 193, Temperature: 14.3745
# Board configuration:
# Iteration: 193
# . . . . . . Q .
# . . . . . Q . .
# . . . . Q . . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . . Q
# Q . . . . . . .
# . Q . . . . . .
#
#
# Current cost: 9.0
# Acceptance probability: 0.7571
#
# Iteration 194, Temperature: 14.2307
# Board configuration:
# Iteration: 194
# . . . . . . Q .
# . . . . . Q . .
# . . . . Q . . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# Q . . . . . . .
#
#
# Current cost: 8.0
# Acceptance probability: 1.0000
#
# Iteration 195, Temperature: 14.0884
# Board configuration:
# Iteration: 195
# . . Q . . . . .
# . . . . . Q . .
# . . . . Q . . .
# . . . . . . Q .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# Q . . . . . . .
#
#
# Current cost: 7.0
# Acceptance probability: 1.0000
#
# Iteration 196, Temperature: 13.9476
# Board configuration:
# Iteration: 196
# . . . . Q . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . Q .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# Q . . . . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 197, Temperature: 13.8081
# Board configuration:
# Iteration: 197
# . . . . Q . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . Q .
# . . . . . . . Q
# . . . Q . . . .
# . Q . . . . . .
# Q . . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 198, Temperature: 13.6700
# Board configuration:
# Iteration: 198
# . . . . Q . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . Q .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# Q . . . . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.9295
#
# Iteration 199, Temperature: 13.5333
# Board configuration:
# Iteration: 199
# . . . . Q . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . . . . Q .
# . . . Q . . . .
# . . Q . . . . .
# . Q . . . . . .
# Q . . . . . . .
#
#
# Current cost: 8.0
# Acceptance probability: 0.8012
#
# Iteration 200, Temperature: 13.3980
# Board configuration:
# Iteration: 200
# . . . . Q . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . Q . . . .
# . . . . . . Q .
# . . Q . . . . .
# . Q . . . . . .
# Q . . . . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 201, Temperature: 13.2640
# Board configuration:
# Iteration: 201
# . Q . . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . Q . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . Q . . .
# Q . . . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 202, Temperature: 13.1313
# Board configuration:
# Iteration: 202
# . Q . . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . Q . . . .
# . . . . Q . . .
# . . Q . . . . .
# . . . . . . Q .
# Q . . . . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.8587
#
# Iteration 203, Temperature: 13.0000
# Board configuration:
# Iteration: 203
# . . . . . . . Q
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . Q . . .
# . . Q . . . . .
# . . . . . . Q .
# Q . . . . . . .
#
#
# Current cost: 7.0
# Acceptance probability: 0.8574
#
# Iteration 204, Temperature: 12.8700
# Board configuration:
# Iteration: 204
# . . . . . . . Q
# . . . . . Q . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . Q . . .
# . . Q . . . . .
# . . . . . . Q .
# Q . . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 205, Temperature: 12.7413
# Board configuration:
# Iteration: 205
# . Q . . . . . .
# . . . . . Q . .
# . . . Q . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . Q . . . . .
# . . . . . . Q .
# Q . . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 206, Temperature: 12.6139
# Board configuration:
# Iteration: 206
# . Q . . . . . .
# . . . . . Q . .
# . . . Q . . . .
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . . . . . . Q .
# Q . . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 207, Temperature: 12.4878
# Board configuration:
# Iteration: 207
# . Q . . . . . .
# . . . . . Q . .
# . . . Q . . . .
# . . . . Q . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . . . . Q .
# Q . . . . . . .
#
#
# Current cost: 6.0
# Acceptance probability: 0.8520
#
# Iteration 208, Temperature: 12.3629
# Board configuration:
# Iteration: 208
# Q . . . . . . .
# . . . . . Q . .
# . . . Q . . . .
# . . . . Q . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . Q . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 209, Temperature: 12.2393
# Board configuration:
# Iteration: 209
# Q . . . . . . .
# . . . . . Q . .
# . . . Q . . . .
# . . . . Q . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . Q . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.7212
#
# Iteration 210, Temperature: 12.1169
# Board configuration:
# Iteration: 210
# Q . . . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . Q . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . . . Q . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 211, Temperature: 11.9957
# Board configuration:
# Iteration: 211
# Q . . . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . . . . . . Q .
# . . . Q . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.8464
#
# Iteration 212, Temperature: 11.8758
# Board configuration:
# Iteration: 212
# Q . . . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . . . . . Q
# . . Q . . . . .
# . . . Q . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 213, Temperature: 11.7570
# Board configuration:
# Iteration: 213
# Q . . . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . Q .
# . . . Q . . . .
# . . . . . . . Q
# . . Q . . . . .
# . . . . Q . . .
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 214, Temperature: 11.6394
# Board configuration:
# Iteration: 214
# Q . . . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . . . . Q .
# . . . Q . . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . Q . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.8421
#
# Iteration 215, Temperature: 11.5230
# Board configuration:
# Iteration: 215
# Q . . . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . . . . Q .
# . . . Q . . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . Q . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.8407
#
# Iteration 216, Temperature: 11.4078
# Board configuration:
# Iteration: 216
# Q . . . . . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . Q . .
# . . . . Q . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 217, Temperature: 11.2937
# Board configuration:
# Iteration: 217
# . . . . Q . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . Q . .
# Q . . . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 218, Temperature: 11.1808
# Board configuration:
# Iteration: 218
# . . . . Q . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . . Q . .
# Q . . . . . . .
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 219, Temperature: 11.0690
# Board configuration:
# Iteration: 219
# . . . . Q . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . Q . .
# Q . . . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.8347
#
# Iteration 220, Temperature: 10.9583
# Board configuration:
# Iteration: 220
# . . . . Q . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . . . Q . . . .
# . Q . . . . . .
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 221, Temperature: 10.8487
# Board configuration:
# Iteration: 221
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . . . . . . Q .
# . . . Q . . . .
# . Q . . . . . .
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.9119
#
# Iteration 222, Temperature: 10.7402
# Board configuration:
# Iteration: 222
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . . . . . . Q .
# . . . Q . . . .
# . Q . . . . . .
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.8301
#
# Iteration 223, Temperature: 10.6328
# Board configuration:
# Iteration: 223
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . . Q . .
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 224, Temperature: 10.5265
# Board configuration:
# Iteration: 224
# . . Q . . . . .
# . . . . . . Q .
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . Q . . .
# . . . . . Q . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.8270
#
# Iteration 225, Temperature: 10.4212
# Board configuration:
# Iteration: 225
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . . Q . .
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 226, Temperature: 10.3170
# Board configuration:
# Iteration: 226
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . . Q . .
#
#
# Current cost: 1.0
# Acceptance probability: 0.6786
#
# Iteration 227, Temperature: 10.2138
# Board configuration:
# Iteration: 227
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . . Q . .
#
#
# Current cost: 1.0
# Acceptance probability: 0.9067
#
# Iteration 228, Temperature: 10.1117
# Board configuration:
# Iteration: 228
# . . Q . . . . .
# . . . . Q . . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . . Q .
# . . . . . Q . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.8205
#
# Iteration 229, Temperature: 10.0106
# Board configuration:
# Iteration: 229
# . . . . Q . . .
# . . Q . . . . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . . Q .
# . . . . . Q . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 230, Temperature: 9.9105
# Board configuration:
# Iteration: 230
# . . . . Q . . .
# . . Q . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . . . Q .
# . . . . . Q . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.8173
#
# Iteration 231, Temperature: 9.8114
# Board configuration:
# Iteration: 231
# . . . . . Q . .
# . . Q . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . . . Q .
# . . . . Q . . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 232, Temperature: 9.7133
# Board configuration:
# Iteration: 232
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . Q . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 233, Temperature: 9.6161
# Board configuration:
# Iteration: 233
# . . . . . Q . .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . Q . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.8122
#
# Iteration 234, Temperature: 9.5200
# Board configuration:
# Iteration: 234
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . Q .
# . . . . Q . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.9003
#
# Iteration 235, Temperature: 9.4248
# Board configuration:
# Iteration: 235
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . Q .
# . . . . Q . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 236, Temperature: 9.3305
# Board configuration:
# Iteration: 236
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . Q .
# . . . . Q . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.8984
#
# Iteration 237, Temperature: 9.2372
# Board configuration:
# Iteration: 237
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . Q . . .
# . . Q . . . . .
# . . . . . . Q .
# . . . . . Q . .
#
#
# Current cost: 6.0
# Acceptance probability: 0.8053
#
# Iteration 238, Temperature: 9.1448
# Board configuration:
# Iteration: 238
# Q . . . . . . .
# . . . Q . . . .
# . . Q . . . . .
# . Q . . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . . . . . . Q .
# . . . . . Q . .
#
#
# Current cost: 14.0
# Acceptance probability: 0.4169
#
# Iteration 239, Temperature: 9.0534
# Board configuration:
# Iteration: 239
# . . . . . . Q .
# . . . Q . . . .
# . . Q . . . . .
# . Q . . . . . .
# . . . . Q . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 8.0
# Acceptance probability: 1.0000
#
# Iteration 240, Temperature: 8.9629
# Board configuration:
# Iteration: 240
# . . . Q . . . .
# . . . . . . Q .
# . . Q . . . . .
# . Q . . . . . .
# . . . . Q . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 241, Temperature: 8.8732
# Board configuration:
# Iteration: 241
# . . . Q . . . .
# . . . . . . Q .
# . . Q . . . . .
# . Q . . . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . . . . Q . .
#
#
# Current cost: 7.0
# Acceptance probability: 0.7131
#
# Iteration 242, Temperature: 8.7845
# Board configuration:
# Iteration: 242
# . . . Q . . . .
# . . . . . . Q .
# . . Q . . . . .
# . Q . . . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . . . . Q . .
#
#
# Current cost: 7.0
# Acceptance probability: 0.7964
#
# Iteration 243, Temperature: 8.6967
# Board configuration:
# Iteration: 243
# . . . Q . . . .
# . . . . . . Q .
# . . . . . . . Q
# . Q . . . . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . . . . . Q . .
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 244, Temperature: 8.6097
# Board configuration:
# Iteration: 244
# . . . . . . Q .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . . . . . Q . .
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 245, Temperature: 8.5236
# Board configuration:
# Iteration: 245
# . . . . . . Q .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . Q . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . Q . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 246, Temperature: 8.4384
# Board configuration:
# Iteration: 246
# . . . . . . Q .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . Q . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . Q . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 247, Temperature: 8.3540
# Board configuration:
# Iteration: 247
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.8872
#
# Iteration 248, Temperature: 8.2704
# Board configuration:
# Iteration: 248
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . Q . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . Q . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 249, Temperature: 8.1877
# Board configuration:
# Iteration: 249
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . Q . . . . .
# . . . . . . Q .
# . . . . . Q . .
# . . . . Q . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.8850
#
# Iteration 250, Temperature: 8.1059
# Board configuration:
# Iteration: 250
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . . . . Q . .
# . . Q . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 251, Temperature: 8.0248
# Board configuration:
# Iteration: 251
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . . . . Q . .
# . . Q . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.4735
#
# Iteration 252, Temperature: 7.9445
# Board configuration:
# Iteration: 252
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . Q . .
# . . . . . . Q .
# . . . . Q . . .
# . . Q . . . . .
#
#
# Current cost: 6.0
# Acceptance probability: 0.7774
#
# Iteration 253, Temperature: 7.8651
# Board configuration:
# Iteration: 253
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . Q . . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 254, Temperature: 7.7864
# Board configuration:
# Iteration: 254
# Q . . . . . . .
# . . . . . . Q .
# . . . . . . . Q
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . Q . . .
# . . Q . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.7735
#
# Iteration 255, Temperature: 7.7086
# Board configuration:
# Iteration: 255
# Q . . . . . . .
# . . . . . . Q .
# . . . Q . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . Q . . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 256, Temperature: 7.6315
# Board configuration:
# Iteration: 256
# . . . Q . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . Q . . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 257, Temperature: 7.5552
# Board configuration:
# Iteration: 257
# . . . . Q . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . . Q . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.8760
#
# Iteration 258, Temperature: 7.4796
# Board configuration:
# Iteration: 258
# . . . . Q . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . . Q . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.7654
#
# Iteration 259, Temperature: 7.4048
# Board configuration:
# Iteration: 259
# . . . . Q . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . . Q . .
# Q . . . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . . Q . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 260, Temperature: 7.3308
# Board configuration:
# Iteration: 260
# . Q . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . . . Q . .
# Q . . . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . . Q . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.8725
#
# Iteration 261, Temperature: 7.2575
# Board configuration:
# Iteration: 261
# . Q . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . . . Q . .
# . . Q . . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 262, Temperature: 7.1849
# Board configuration:
# Iteration: 262
# . Q . . . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . Q . . . .
# . . . . Q . . .
# . . . . . . . Q
# . . . . . Q . .
# . . Q . . . . .
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 263, Temperature: 7.1131
# Board configuration:
# Iteration: 263
# . Q . . . . . .
# . . . . . . Q .
# . . . . . Q . .
# . . . Q . . . .
# . . . . Q . . .
# . . . . . . . Q
# Q . . . . . . .
# . . Q . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.7549
#
# Iteration 264, Temperature: 7.0419
# Board configuration:
# Iteration: 264
# . Q . . . . . .
# . . . . . . Q .
# . . . . . Q . .
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 265, Temperature: 6.9715
# Board configuration:
# Iteration: 265
# . Q . . . . . .
# . . . . . . Q .
# . . . . . Q . .
# . . . Q . . . .
# . . . . Q . . .
# . . . . . . . Q
# Q . . . . . . .
# . . Q . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.7506
#
# Iteration 266, Temperature: 6.9018
# Board configuration:
# Iteration: 266
# . Q . . . . . .
# Q . . . . . . .
# . . . . . Q . .
# . . . Q . . . .
# . . . . Q . . .
# . . . . . . . Q
# . . . . . . Q .
# . . Q . . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.7484
#
# Iteration 267, Temperature: 6.8328
# Board configuration:
# Iteration: 267
# . . . . Q . . .
# Q . . . . . . .
# . . . . . Q . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . . Q . . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 268, Temperature: 6.7644
# Board configuration:
# Iteration: 268
# . . Q . . . . .
# Q . . . . . . .
# . . . . . Q . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . . . Q .
# . . . . Q . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.7440
#
# Iteration 269, Temperature: 6.6968
# Board configuration:
# Iteration: 269
# . . Q . . . . .
# Q . . . . . . .
# . . . . . Q . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . . . . . Q .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 270, Temperature: 6.6298
# Board configuration:
# Iteration: 270
# . . Q . . . . .
# . . . . Q . . .
# . . . . . Q . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . . . Q .
#
#
# Current cost: 4.0
# Acceptance probability: 0.7396
#
# Iteration 271, Temperature: 6.5635
# Board configuration:
# Iteration: 271
# . Q . . . . . .
# . . . . Q . . .
# . . . . . Q . .
# . . . Q . . . .
# . . Q . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . . . Q .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 272, Temperature: 6.4979
# Board configuration:
# Iteration: 272
# . Q . . . . . .
# . . . . Q . . .
# . . . . . Q . .
# . . . Q . . . .
# . . . . . . Q .
# . . . . . . . Q
# Q . . . . . . .
# . . Q . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 273, Temperature: 6.4329
# Board configuration:
# Iteration: 273
# . Q . . . . . .
# . . . . Q . . .
# . . . . . Q . .
# . . . Q . . . .
# . . . . . . Q .
# . . . . . . . Q
# Q . . . . . . .
# . . Q . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.3935
#
# Iteration 274, Temperature: 6.3686
# Board configuration:
# Iteration: 274
# . Q . . . . . .
# . . . . Q . . .
# . . . . . Q . .
# . . . Q . . . .
# . . . . . . Q .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . . Q
#
#
# Current cost: 4.0
# Acceptance probability: 0.8547
#
# ...
# Board configuration:
# Iteration: 341
# . . Q . . . . .
# . . . . Q . . .
# . . . Q . . . .
# . . . . . Q . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . . Q .
# Q . . . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 342, Temperature: 3.2154
# Board configuration:
# Iteration: 342
# . . Q . . . . .
# . . . . Q . . .
# . . . Q . . . .
# . . . . . Q . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . . Q .
# Q . . . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.3934
#
# Iteration 343, Temperature: 3.1833
# Board configuration:
# Iteration: 343
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . . . . Q . .
# . . . . . . . Q
# . Q . . . . . .
# . . . Q . . . .
# Q . . . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 344, Temperature: 3.1514
# Board configuration:
# Iteration: 344
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . . . . Q . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
# Q . . . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 345, Temperature: 3.1199
# Board configuration:
# Iteration: 345
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . . . . Q . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
# Q . . . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 0.2775
#
# Iteration 346, Temperature: 3.0887
# Board configuration:
# Iteration: 346
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . Q .
# . . . . . Q . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# Q . . . . . . .
#
#
# Current cost: 6.0
# Acceptance probability: 0.3786
#
# Iteration 347, Temperature: 3.0578
# Board configuration:
# Iteration: 347
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . . Q . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . Q . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 348, Temperature: 3.0272
# Board configuration:
# Iteration: 348
# Q . . . . . . .
# . . Q . . . . .
# . . . . . . Q .
# . . . . . Q . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . Q . . . .
#
#
# Current cost: 6.0
# Acceptance probability: 0.7187
#
# Iteration 349, Temperature: 2.9970
# Board configuration:
# Iteration: 349
# Q . . . . . . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . Q . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . . . Q .
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 350, Temperature: 2.9670
# Board configuration:
# Iteration: 350
# . . Q . . . . .
# Q . . . . . . .
# . . . Q . . . .
# . . . . . Q . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . . . Q .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 351, Temperature: 2.9373
# Board configuration:
# Iteration: 351
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
# . . . . . Q . .
# . . . . Q . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . . . Q .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 352, Temperature: 2.9080
# Board configuration:
# Iteration: 352
# . . . . . Q . .
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . . . Q . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . . . Q .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 353, Temperature: 2.8789
# Board configuration:
# Iteration: 353
# . . . . . Q . .
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . Q . . . . .
# . Q . . . . . .
# . . . . Q . . .
# . . . . . . Q .
#
#
# Current cost: 5.0
# Acceptance probability: 0.7066
#
# Iteration 354, Temperature: 2.8501
# Board configuration:
# Iteration: 354
# . . . . . Q . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . . Q . . . . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . Q .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 355, Temperature: 2.8216
# Board configuration:
# Iteration: 355
# . . . . . Q . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . . Q . . . . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . Q .
#
#
# Current cost: 4.0
# Acceptance probability: 0.3453
#
# Iteration 356, Temperature: 2.7934
# Board configuration:
# Iteration: 356
# . . Q . . . . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . Q .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 357, Temperature: 2.7654
# Board configuration:
# Iteration: 357
# . . Q . . . . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . Q .
#
#
# Current cost: 4.0
# Acceptance probability: 0.2354
#
# Iteration 358, Temperature: 2.7378
# Board configuration:
# Iteration: 358
# . . Q . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . . . . . Q
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
# Q . . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 359, Temperature: 2.7104
# Board configuration:
# Iteration: 359
# . . Q . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . . . . . Q
# . . . . . Q . .
# . Q . . . . . .
# . . . Q . . . .
# Q . . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.6915
#
# Iteration 360, Temperature: 2.6833
# Board configuration:
# Iteration: 360
# . . Q . . . . .
# . . . Q . . . .
# . . . . Q . . .
# . . . . . . . Q
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . Q .
# Q . . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 361, Temperature: 2.6565
# Board configuration:
# Iteration: 361
# . . Q . . . . .
# . . . Q . . . .
# . . . . Q . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . Q . .
# . . . . . . Q .
# Q . . . . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.6863
#
# Iteration 362, Temperature: 2.6299
# Board configuration:
# Iteration: 362
# . . Q . . . . .
# . . . . . Q . .
# . . . . Q . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . Q .
# Q . . . . . . .
#
#
# Current cost: 3.0
# Acceptance probability: 1.0000
#
# Iteration 363, Temperature: 2.6036
# Board configuration:
# Iteration: 363
# . Q . . . . . .
# . . . . . Q . .
# . . . . Q . . .
# . . . . . . . Q
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . Q .
# Q . . . . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.4639
#
# Iteration 364, Temperature: 2.5776
# Board configuration:
# Iteration: 364
# . Q . . . . . .
# . . . . . Q . .
# . . . . Q . . .
# . . . . . . . Q
# . . . Q . . . .
# . . Q . . . . .
# . . . . . . Q .
# Q . . . . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 365, Temperature: 2.5518
# Board configuration:
# Iteration: 365
# . Q . . . . . .
# . . . . . Q . .
# . . . . . . Q .
# . . . . . . . Q
# . . . Q . . . .
# . . Q . . . . .
# . . . . Q . . .
# Q . . . . . . .
#
#
# Current cost: 7.0
# Acceptance probability: 0.4567
#
# Iteration 366, Temperature: 2.5263
# Board configuration:
# Iteration: 366
# . Q . . . . . .
# . . . . . Q . .
# . . . . . . Q .
# . . . . . . . Q
# Q . . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . . . Q . . . .
#
#
# Current cost: 7.0
# Acceptance probability: 1.0000
#
# Iteration 367, Temperature: 2.5010
# Board configuration:
# Iteration: 367
# . . . . . . . Q
# . . . . . Q . .
# . . . . . . Q .
# . Q . . . . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . . . Q . . . .
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 368, Temperature: 2.4760
# Board configuration:
# Iteration: 368
# . . . . . . . Q
# . . . . . Q . .
# . . . . Q . . .
# . Q . . . . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . . Q .
# . . . Q . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 369, Temperature: 2.4512
# Board configuration:
# Iteration: 369
# . . . . . . . Q
# . . . . . Q . .
# . Q . . . . . .
# . . . . Q . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . . Q .
# . . . Q . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 370, Temperature: 2.4267
# Board configuration:
# Iteration: 370
# . . . . . Q . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . Q . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . . Q .
# . . . Q . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 371, Temperature: 2.4025
# Board configuration:
# Iteration: 371
# . . . . . Q . .
# . . . . . . . Q
# . . . Q . . . .
# . . . . Q . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . . Q .
# . Q . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.4350
#
# Iteration 372, Temperature: 2.3784
# Board configuration:
# Iteration: 372
# . . . . . Q . .
# . . . . . . . Q
# . . . Q . . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . Q . . . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.6568
#
# Iteration 373, Temperature: 2.3547
# Board configuration:
# Iteration: 373
# . . . . . Q . .
# . . . . . . . Q
# . . . Q . . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . Q . . . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.6540
#
# Iteration 374, Temperature: 2.3311
# Board configuration:
# Iteration: 374
# . . . . . Q . .
# . . . . . . . Q
# . . . Q . . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . Q . . . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 0.6512
#
# Iteration 375, Temperature: 2.3078
# Board configuration:
# Iteration: 375
# . . . . . Q . .
# . . . . . . . Q
# . . . Q . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . Q . . .
# . . Q . . . . .
# . Q . . . . . .
#
#
# Current cost: 6.0
# Acceptance probability: 0.6484
#
# Iteration 376, Temperature: 2.2847
# Board configuration:
# Iteration: 376
# . . . . . Q . .
# . . . . . . . Q
# . . . Q . . . .
# . . . . . . Q .
# Q . . . . . . .
# . Q . . . . . .
# . . Q . . . . .
# . . . . Q . . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 377, Temperature: 2.2619
# Board configuration:
# Iteration: 377
# . . . . . Q . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . Q .
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 378, Temperature: 2.2393
# Board configuration:
# Iteration: 378
# . . . . . Q . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 379, Temperature: 2.2169
# Board configuration:
# Iteration: 379
# . . . . . Q . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
#
#
# Current cost: 1.0
# Acceptance probability: 0.2584
#
# Iteration 380, Temperature: 2.1947
# Board configuration:
# Iteration: 380
# . . . . . Q . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
#
#
# Current cost: 1.0
# Acceptance probability: 0.2549
#
# Iteration 381, Temperature: 2.1727
# Board configuration:
# Iteration: 381
# . . . . . Q . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . Q . . . .
# . Q . . . . . .
# . . . . Q . . .
# . . . . . . . Q
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 382, Temperature: 2.1510
# Board configuration:
# Iteration: 382
# . . . . Q . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . Q . .
# . . . . . . . Q
#
#
# Current cost: 1.0
# Acceptance probability: 1.0000
#
# Iteration 383, Temperature: 2.1295
# Board configuration:
# Iteration: 383
# . . . . Q . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . Q . .
# . . . . . . . Q
#
#
# Current cost: 1.0
# Acceptance probability: 0.3909
#
# Iteration 384, Temperature: 2.1082
# Board configuration:
# Iteration: 384
# . . . Q . . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . Q . .
# . . . . . . . Q
#
#
# Current cost: 3.0
# Acceptance probability: 0.3873
#
# Iteration 385, Temperature: 2.0871
# Board configuration:
# Iteration: 385
# . . . . . Q . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . . Q
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 386, Temperature: 2.0663
# Board configuration:
# Iteration: 386
# . . . . . Q . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . . . . . Q
# . . . Q . . . .
# . Q . . . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 387, Temperature: 2.0456
# Board configuration:
# Iteration: 387
# . . . . . Q . .
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . Q . . . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 388, Temperature: 2.0251
# Board configuration:
# Iteration: 388
# . . . . . Q . .
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . Q . . . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 0.6103
#
# Iteration 389, Temperature: 2.0049
# Board configuration:
# Iteration: 389
# . . . . . Q . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . Q . . . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 390, Temperature: 1.9848
# Board configuration:
# Iteration: 390
# . . . . . Q . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . Q . . . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 0.2206
#
# Iteration 391, Temperature: 1.9650
# Board configuration:
# Iteration: 391
# . . . . . Q . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . Q . . . . . .
#
#
# Current cost: 2.0
# Acceptance probability: 0.3614
#
# Iteration 392, Temperature: 1.9453
# Board configuration:
# Iteration: 392
# . . . . . Q . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# Q . . . . . . .
#
#
# Current cost: 4.0
# Acceptance probability: 0.3577
#
# Iteration 393, Temperature: 1.9259
# Board configuration:
# Iteration: 393
# Q . . . . . . .
# . . Q . . . . .
# . . . Q . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . . . . Q . .
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 394, Temperature: 1.9066
# Board configuration:
# Iteration: 394
# . . . . . . Q .
# . . Q . . . . .
# . . . Q . . . .
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . . . . Q . .
#
#
# Current cost: 6.0
# Acceptance probability: 0.3503
#
# Iteration 395, Temperature: 1.8876
# Board configuration:
# Iteration: 395
# . . . . . . Q .
# . . Q . . . . .
# . . . Q . . . .
# . Q . . . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . . . . Q . .
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 396, Temperature: 1.8687
# Board configuration:
# Iteration: 396
# . . . . . . Q .
# . . Q . . . . .
# . . . Q . . . .
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . . . . Q . .
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 397, Temperature: 1.8500
# Board configuration:
# Iteration: 397
# . . . . . Q . .
# . . Q . . . . .
# . . . Q . . . .
# Q . . . . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . . . . . Q .
#
#
# Current cost: 6.0
# Acceptance probability: 1.0000
#
# Iteration 398, Temperature: 1.8315
# Board configuration:
# Iteration: 398
# . . . . . Q . .
# . . Q . . . . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . . . . Q
# . . . . Q . . .
# . Q . . . . . .
#
#
# Current cost: 5.0
# Acceptance probability: 1.0000
#
# Iteration 399, Temperature: 1.8132
# Board configuration:
# Iteration: 399
# . . . . . Q . .
# . . Q . . . . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . Q . . .
# . . . . . . . Q
#
#
# Current cost: 4.0
# Acceptance probability: 1.0000
#
# Iteration 400, Temperature: 1.7951
# Board configuration:
# Iteration: 400
# . . . . Q . . .
# . . Q . . . . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . . Q . .
# . . . . . . . Q
#
#
# Current cost: 2.0
# Acceptance probability: 1.0000
#
# Iteration 401, Temperature: 1.7771
# Board configuration:
# Iteration: 401
# . . . . Q . . .
# . . . . . . . Q
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . . Q . .
# . . Q . . . . .
#
#
# Current cost: 0
# Acceptance probability: 1.0000
#
# Solution found!
# Iteration: 401
# . . . . Q . . .
# . . . . . . . Q
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . . Q . .
# . . Q . . . . .
#
#
# Runtime in seconds: 1.8313300609588623
